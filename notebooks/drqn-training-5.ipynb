# %%
from tournament.agents.constant import AllC, AllD
from tournament.agents.pavlov import Pavlov
from tournament.agents.q_learning.dqn import DeepQLearner
from tournament.agents.tft import TFTT, GenerousTFT, TitForTat, OmegaTFT, TTFT
from tournament.environments.single import SingleRuleBasedAgentEnvironment
from tournament.environments.multiple import MultipleRuleBasedAgentEnvironment
from tournament.action import Action
from tournament.agents.agents import AGENTS
from tournament.agents.axelrod_first import (
    Davis,
    Downing,
    Feld,
    Grofman,
    Grudger,
    Joss,
    Nydegger,
    Shubik,
    SteinAndRapoport,
    TidemanAndChieruzzi,
    Tullock,
)
from tournament.agents.axelrod_second import (
    Borufsen,
    Champion,
    Leyvraz,
    SecondByBlackK83R,
    Cave,
    GraaskampAndKatzen,
    Harrington,
    TidemanAndChieruzzi2,
    Weiner,
    White,
    Adams,
)
from tournament.tournament import RoundRobinTournament

import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# plt.rcParams["figure.figsize"] = (20, 12)
plt.rcParams["figure.figsize"] = (10, 6)

# %%
# agents = [TitForTat, Joss, Downing]
# ['TitForTat', 'TFTT', 'TTFT', 'GenerousTFT', 'OmegaTFT', 'Davis', 'Grofman', 'Leyvraz']
agents = [TitForTat, TFTT, TTFT, GenerousTFT, OmegaTFT, Davis, Grofman, Leyvraz]

env = MultipleRuleBasedAgentEnvironment(agents)

# %%
class QNetwork(nn.Module):
    def __init__(self, lookback):
        super().__init__()

        self.flatten = nn.Flatten()
        self.gru = nn.GRU(2, 2, 1, batch_first=True)
        self.linear1 = nn.Linear(2 * lookback, 2 * lookback)
        self.linear2 = nn.Linear(2 * lookback, 2)

        nn.init.kaiming_uniform_(self.linear1.weight, mode="fan_in", nonlinearity="relu")
        nn.init.kaiming_uniform_(self.linear2.weight, mode="fan_in", nonlinearity="relu")

    def forward(self, x):
        x = x.unsqueeze(dim=0)
        x, hn = self.gru(x)
        x = self.flatten(x)
        x = torch.relu(self.linear1(x))
        x = torch.relu(self.linear2(x))

        return x

class QLearningTest(DeepQLearner):
    def __init__(self):
        super().__init__()

        self.lookback = 4
        self.epsilon = 0.2

        self._learning_rate = 0.05
        self._discount_rate = 0.99
        self._q_network = QNetwork(self.lookback)


agent = QLearningTest()

# %%
env.train(
    trainee=agent,
    limit=100,
    epochs=10,
)
# Out:
# [00:29:20] Commencement of training.
# BEFORE: tensor([[0.0000, 0.0176]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.2574]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.2574]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.3970]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.3741]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.4362]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.4007]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.4230]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5107]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5004]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5734]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5629]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5693]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5754]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5754]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5992]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5992]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.6471]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.6471]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.7105]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.7105]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.7850]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.7850]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.8677]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.8677]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.7419]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.7419]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.6617]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.6613]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.6315]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.6443]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.6269]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.6229]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.6043]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.6054]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5858]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5821]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5630]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5672]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5526]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5526]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5433]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5433]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5396]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5396]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5418]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5418]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5501]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5501]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5648]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5648]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5875]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5875]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.6159]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.6159]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.6500]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.6500]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.6900]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.6900]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.7359]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.7359]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.7879]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.7879]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.8462]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.8462]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.9112]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.9112]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.9832]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.9832]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 1.0630]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 1.0630]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 1.1510]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 1.1510]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 1.2483]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 1.2483]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 1.3557]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 1.3557]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 1.1816]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 1.1816]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 1.0373]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 1.0234]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.9059]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.8996]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.8048]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.8014]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.6606]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.6776]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.5598]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.5543]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.4549]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.4465]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.3661]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.3677]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.3009]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.3142]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.2406]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.2317]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1693]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1611]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1236]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1239]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0945]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0989]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0766]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0706]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0507]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0481]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0389]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0388]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0233]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0234]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0104]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0106]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# ...
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jerem\Documents\GitHub\tournament\drqn-training-5.ipynb Cell 4' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jerem/Documents/GitHub/tournament/drqn-training-5.ipynb#ch0000003?line=0'>1</a> env.train(
#       <a href='vscode-notebook-cell:/c%3A/Users/jerem/Documents/GitHub/tournament/drqn-training-5.ipynb#ch0000003?line=1'>2</a>     trainee=agent,
#       <a href='vscode-notebook-cell:/c%3A/Users/jerem/Documents/GitHub/tournament/drqn-training-5.ipynb#ch0000003?line=2'>3</a>     limit=100,
#       <a href='vscode-notebook-cell:/c%3A/Users/jerem/Documents/GitHub/tournament/drqn-training-5.ipynb#ch0000003?line=3'>4</a>     epochs=10,
#       <a href='vscode-notebook-cell:/c%3A/Users/jerem/Documents/GitHub/tournament/drqn-training-5.ipynb#ch0000003?line=4'>5</a> )
#
# File c:\Users\jerem\Documents\GitHub\tournament\tournament\environment.py:69, in Environment.train(self, trainee, continuation_probability, limit, noise, repetitions, epochs)
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=65'>66</a> for i in range(epochs):
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=66'>67</a>     self.epoch_count = {Action.COOPERATE: 0, Action.DEFECT: 0}
# ---> <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=68'>69</a>     self._play_epoch(
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=69'>70</a>         trainee, continuation_probability, limit, noise, repetitions
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=70'>71</a>     )
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=72'>73</a>     s = sum(self.epoch_count.values())
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=73'>74</a>     self.epoch_counts.append(self.epoch_count)
#
# File c:\Users\jerem\Documents\GitHub\tournament\tournament\environments\multiple.py:28, in MultipleRuleBasedAgentEnvironment._play_epoch(self, trainee, continuation_probability, limit, noise, repetitions)
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=22'>23</a> for opponent in random.sample(self.agents, len(self.agents)):
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=23'>24</a>     # print(
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=24'>25</a>     #     f"[{datetime.now().strftime('%H:%M:%S')}] Training against {opponent.__name__}"
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=25'>26</a>     # )
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=26'>27</a>     for _ in range(repetitions):
# ---> <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=27'>28</a>         self._play_training_match(
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=28'>29</a>             trainee, opponent(), continuation_probability, limit, noise
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=29'>30</a>         )
#
# File c:\Users\jerem\Documents\GitHub\tournament\tournament\environment.py:37, in Environment._play_training_match(self, trainee, opponent, continuation_probability, limit, noise)
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=33'>34</a>     self.epoch_count[moves[0]] += 1
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=34'>35</a>     self.rewards.append(rewards[0])
# ---> <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=36'>37</a>     trainee.update(moves, scores, rewards)
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=38'>39</a> trainee.notify_postmatch()
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=39'>40</a> self.metric_history.append(trainee.metric)
#
# File c:\Users\jerem\Documents\GitHub\tournament\tournament\agents\q_learning\dqn.py:161, in DeepQLearner.update(self, moves, scores, rewards)
#     <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/agents/q_learning/dqn.py?line=156'>157</a> self._optimiser.zero_grad()
#     <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/agents/q_learning/dqn.py?line=158'>159</a> prediction = self._values[0, moves[0].value]
#     <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/agents/q_learning/dqn.py?line=159'>160</a> target = (
# --> <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/agents/q_learning/dqn.py?line=160'>161</a>     rewards[0] + self._discount_rate * self._q_network(self._state)[0].max()
#     <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/agents/q_learning/dqn.py?line=161'>162</a> )
#     <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/agents/q_learning/dqn.py?line=163'>164</a> loss = self._criterion(prediction, target)
#     <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/agents/q_learning/dqn.py?line=164'>165</a> self._loss += float(loss)
#
# KeyboardInterrupt:

# %%
print(agent._q_network)
print(env.counts)

s = sum(env.counts.values())
print({a: env.counts[a] / s for a in env.counts})

# %%
plt.title("Loss")
plt.plot(env.metric_history)
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
plt.title("Rewards")
plt.plot(env.rewards)
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
N = 20

plt.title("Rolling average of rewards")
plt.plot(np.convolve(env.rewards, np.ones(N), mode='valid') / N)
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
plt.title("Cumulative reward")
plt.plot(np.cumsum(env.rewards))
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
plt.title("Cumulative regret (vs cooperating)")
plt.plot(np.cumsum(3 - np.array(env.rewards)))
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
plt.title("Cooperation over the epochs")
print(env.normalised_epoch_counts)
plt.plot([x[Action.COOPERATE] for x in env.normalised_epoch_counts])
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
# torch.save(agent._q_network.state_dict(), "models/drqn/gru-1.pt")

# %%
agent._q_network.eval()

# %%
tournament = RoundRobinTournament(AGENTS, [agent])

scores, times = tournament.play(
    continuation_probability=0.99654, repetitions=20, jobs=12
)

results = [
    (a, round(sum(scores[a]) / len(scores[a])), sum(times[a]))
    for a in scores
]
results.sort(key=lambda x: x[1], reverse=True)

for c, score, time in results:
    print(f"{c.__name__:<30} {score:<20} {time:<20}")

# %%
from tournament.agent import Agent
from tournament.match import Match

class ManualAgent(Agent):
    def play_move(self, history, opp_history):
        move = input("Move: ")
        if move == "C":
            return Action.COOPERATE
        elif move == "D":
            return Action.DEFECT
        elif move == "Q":
            raise RuntimeError()

manual_agent = ManualAgent()

match = Match(agent, manual_agent)

for i, ((move1, move2), (score1, score2), (reward1, reward2)) in enumerate(
    match.play_moves(continuation_probability=0.99654, limit=1000, noise=0)
):
    print(agent._q_network(agent._prev_state), agent._q_network(agent._state))
    print(
        f"{i:<4} | \t {move1:<20} {score1:<8} {f'({reward1})':<20} {move2:<20} {score2:<8} {f'({reward2})':<10}"
    )
