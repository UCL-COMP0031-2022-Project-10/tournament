# %%
from tournament.agents.constant import AllC, AllD
from tournament.agents.pavlov import Pavlov
from tournament.agents.q_learning.dqn import DeepQLearner
from tournament.agents.tft import TFTT, GenerousTFT, TitForTat, OmegaTFT
from tournament.environments.single import SingleRuleBasedAgentEnvironment
from tournament.environments.multiple import MultipleRuleBasedAgentEnvironment
from tournament.action import Action
from tournament.agents.agents import AGENTS
from tournament.agents.axelrod_first import (
    Davis,
    Downing,
    Feld,
    Grofman,
    Grudger,
    Joss,
    Nydegger,
    Shubik,
    SteinAndRapoport,
    TidemanAndChieruzzi,
    Tullock,
)
from tournament.agents.axelrod_second import (
    Borufsen,
    Champion,
    Leyvraz,
    SecondByBlackK83R,
    SecondByCave,
    SecondByGraaskampKatzen,
    SecondByHarrington,
    SecondByTidemanAndChieruzzi,
    SecondByWeiner,
    SecondByWhiteK72R,
    SecondByWmAdams,
)
from tournament.tournament import RoundRobinTournament

import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# plt.rcParams["figure.figsize"] = (20, 12)
plt.rcParams["figure.figsize"] = (10, 6)

# %%
agents = [TitForTat, Pavlov, SecondByWeiner, Borufsen, Leyvraz, SecondByWhiteK72R]

env = MultipleRuleBasedAgentEnvironment(agents)

# %%
class QNetwork(nn.Module):
    def __init__(self, lookback):
        super().__init__()

        self.flatten = nn.Flatten()
        self.layer1 = nn.Linear(2 * lookback, 10)
        self.layer2 = nn.Linear(10, 10)
        # self.layer3 = nn.Linear(6, 6)
        self.layer4 = nn.Linear(10, 2)

        nn.init.kaiming_uniform_(self.layer1.weight, mode='fan_in', nonlinearity='relu')
        nn.init.kaiming_uniform_(self.layer2.weight, mode='fan_in', nonlinearity='relu')
        # nn.init.kaiming_uniform_(self.layer3.weight, mode='fan_in', nonlinearity='relu')
        nn.init.kaiming_uniform_(self.layer4.weight, mode='fan_in', nonlinearity='relu')

    def forward(self, x):
        x = x.unsqueeze(dim=0)
        x = self.flatten(x)
        x = torch.tanh(self.layer1(x))
        x = torch.tanh(self.layer2(x))
        # x = torch.relu(self.layer3(x))
        x = torch.relu(self.layer4(x))

        return x

class QLearningTest(DeepQLearner):
    def __init__(self):
        super().__init__()

        self.lookback = 4
        self.epsilon = 0.2

        self._learning_rate = 0.0001
        self._discount_rate = 0.99
        self._q_network = QNetwork(self.lookback)


agent = QLearningTest()

# %%
env.train(
    trainee=agent,
    limit=200,
    epochs=100,
)
# Out:
# [00:39:59] Commencement of training.
# BEFORE: tensor([[0.0000, 0.1909]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1897]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1897]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1889]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0256, 0.1904]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0246, 0.1903]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0393, 0.2195]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0378, 0.2199]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.2883, 0.0000]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.2864, 0.0000]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.2107, 0.1564]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.2085, 0.1573]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.2085, 0.1573]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.2063, 0.1582]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0478, 0.0945]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0461, 0.0954]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.2981, 0.1892]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.2967, 0.1899]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1916]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1919]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1919]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1921]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.1998, 0.1617]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.1985, 0.1625]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.1985, 0.1625]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.1969, 0.1633]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.2928, 0.1918]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.2917, 0.1925]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.1078, 0.1190]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.1066, 0.1197]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1330]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1334]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1941]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1944]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.1330, 0.1253]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.1320, 0.1256]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.1701, 0.0445]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.1690, 0.0452]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.1324, 0.1361]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.1311, 0.1366]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1953]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1955]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1955]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1957]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.3556, 0.0462]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.3544, 0.0468]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0267, 0.1061]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0256, 0.1067]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0310, 0.0000]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0302, 0.0000]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0365]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0369]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0988, 0.0000]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0981, 0.0000]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0868, 0.1641]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0857, 0.1648]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.2570, 0.0000]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.2559, 0.0000]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1977]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1978]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.1561, 0.0517]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.
], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1770]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0946]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0951]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0244, 0.2272]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0245, 0.2278]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0957]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0963]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1788]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1794]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0968]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0972]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1799]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1802]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0250, 0.2295]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0251, 0.2297]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.2563]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.2564]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0610, 0.0820]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0611, 0.0821]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1112]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1112]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0524]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0524]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.2277]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.2273]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.2634]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.2632]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1323]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1321]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1321]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1320]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0484]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0483]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0586, 0.0813]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0581, 0.0813]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1629]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1628]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0487, 0.1043]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0486, 0.1041]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0680]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0678]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.2621]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.2618]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1860]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1858]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0497]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0493]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.2611]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.2608]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1297]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1294]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0457]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0455]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0562, 0.0790]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0559, 0.0788]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.2558]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.2557]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0649]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0647]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0479, 0.1584]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0478, 0.1584]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0933]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0933]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1283]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1284]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0477, 0.1586]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0478, 0.1590]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0., 0.]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0461]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0466]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0955]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0961]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0961]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0968]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.2622]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.2628]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0975]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0982]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0982]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0988]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0988]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0994]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0994]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0999]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0999]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1004]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1004]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1008]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0789, 0.2285]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0790, 0.2289]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.2595]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.2596]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0549]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0550]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1018]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1018]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.2056]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.2056]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1016]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1014]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1486]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1483]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0881]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0877]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0798]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0795]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0483, 0.1069]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0483, 0.1065]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.1134]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.1133]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0995]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0993]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0000, 0.0993]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0000, 0.0990]], grad_fn=<ReluBackward0>)
# BEFORE: tensor([[0.0330, 0.1869]], grad_fn=<ReluBackward0>)
# AFTER: tensor([[0.0326, 0.1865]], grad_fn=<ReluBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jerem\Documents\GitHub\tournament\dqn-training-3.ipynb Cell 4' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jerem/Documents/GitHub/tournament/dqn-training-3.ipynb#ch0000003?line=0'>1</a> env.train(
#       <a href='vscode-notebook-cell:/c%3A/Users/jerem/Documents/GitHub/tournament/dqn-training-3.ipynb#ch0000003?line=1'>2</a>     trainee=agent,
#       <a href='vscode-notebook-cell:/c%3A/Users/jerem/Documents/GitHub/tournament/dqn-training-3.ipynb#ch0000003?line=2'>3</a>     limit=200,
#       <a href='vscode-notebook-cell:/c%3A/Users/jerem/Documents/GitHub/tournament/dqn-training-3.ipynb#ch0000003?line=3'>4</a>     epochs=100,
#       <a href='vscode-notebook-cell:/c%3A/Users/jerem/Documents/GitHub/tournament/dqn-training-3.ipynb#ch0000003?line=4'>5</a> )
#
# File c:\Users\jerem\Documents\GitHub\tournament\tournament\environment.py:69, in Environment.train(self, trainee, continuation_probability, limit, noise, repetitions, epochs)
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=65'>66</a> for i in range(epochs):
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=66'>67</a>     self.epoch_count = {Action.COOPERATE: 0, Action.DEFECT: 0}
# ---> <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=68'>69</a>     self._play_epoch(
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=69'>70</a>         trainee, continuation_probability, limit, noise, repetitions
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=70'>71</a>     )
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=72'>73</a>     s = sum(self.epoch_count.values())
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=73'>74</a>     self.epoch_counts.append(self.epoch_count)
#
# File c:\Users\jerem\Documents\GitHub\tournament\tournament\environments\multiple.py:28, in MultipleRuleBasedAgentEnvironment._play_epoch(self, trainee, continuation_probability, limit, noise, repetitions)
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=22'>23</a> for opponent in random.sample(self.agents, len(self.agents)):
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=23'>24</a>     # print(
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=24'>25</a>     #     f"[{datetime.now().strftime('%H:%M:%S')}] Training against {opponent.__name__}"
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=25'>26</a>     # )
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=26'>27</a>     for _ in range(repetitions):
# ---> <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=27'>28</a>         self._play_training_match(
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=28'>29</a>             trainee, opponent(), continuation_probability, limit, noise
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environments/multiple.py?line=29'>30</a>         )
#
# File c:\Users\jerem\Documents\GitHub\tournament\tournament\environment.py:37, in Environment._play_training_match(self, trainee, opponent, continuation_probability, limit, noise)
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=33'>34</a>     self.epoch_count[moves[0]] += 1
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=34'>35</a>     self.rewards.append(rewards[0])
# ---> <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=36'>37</a>     trainee.update(moves, scores, rewards)
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=38'>39</a> trainee.notify_postmatch()
#      <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/environment.py?line=39'>40</a> self.metric_history.append(trainee.metric)
#
# File c:\Users\jerem\Documents\GitHub\tournament\tournament\agents\q_learning\dqn.py:166, in DeepQLearner.update(self, moves, scores, rewards)
#     <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/agents/q_learning/dqn.py?line=163'>164</a> loss = self._criterion(prediction, target)
#     <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/agents/q_learning/dqn.py?line=164'>165</a> self._loss += float(loss)
# --> <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/agents/q_learning/dqn.py?line=165'>166</a> loss.backward()
#     <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/agents/q_learning/dqn.py?line=167'>168</a> if self._count % self._batch_size == 0:
#     <a href='file:///c%3A/Users/jerem/Documents/GitHub/tournament/tournament/agents/q_learning/dqn.py?line=168'>169</a>     self._optimiser.step()
#
# File ~\miniconda3\envs\climatehack\lib\site-packages\torch\_tensor.py:307, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     <a href='file:///c%3A/Users/jerem/miniconda3/envs/climatehack/lib/site-packages/torch/_tensor.py?line=297'>298</a> if has_torch_function_unary(self):
#     <a href='file:///c%3A/Users/jerem/miniconda3/envs/climatehack/lib/site-packages/torch/_tensor.py?line=298'>299</a>     return handle_torch_function(
#     <a href='file:///c%3A/Users/jerem/miniconda3/envs/climatehack/lib/site-packages/torch/_tensor.py?line=299'>300</a>         Tensor.backward,
#     <a href='file:///c%3A/Users/jerem/miniconda3/envs/climatehack/lib/site-packages/torch/_tensor.py?line=300'>301</a>         (self,),
#    (...)
#     <a href='file:///c%3A/Users/jerem/miniconda3/envs/climatehack/lib/site-packages/torch/_tensor.py?line=304'>305</a>         create_graph=create_graph,
#     <a href='file:///c%3A/Users/jerem/miniconda3/envs/climatehack/lib/site-packages/torch/_tensor.py?line=305'>306</a>         inputs=inputs)
# --> <a href='file:///c%3A/Users/jerem/miniconda3/envs/climatehack/lib/site-packages/torch/_tensor.py?line=306'>307</a> torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~\miniconda3\envs\climatehack\lib\site-packages\torch\autograd\__init__.py:154, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     <a href='file:///c%3A/Users/jerem/miniconda3/envs/climatehack/lib/site-packages/torch/autograd/__init__.py?line=150'>151</a> if retain_graph is None:
#     <a href='file:///c%3A/Users/jerem/miniconda3/envs/climatehack/lib/site-packages/torch/autograd/__init__.py?line=151'>152</a>     retain_graph = create_graph
# --> <a href='file:///c%3A/Users/jerem/miniconda3/envs/climatehack/lib/site-packages/torch/autograd/__init__.py?line=153'>154</a> Variable._execution_engine.run_backward(
#     <a href='file:///c%3A/Users/jerem/miniconda3/envs/climatehack/lib/site-packages/torch/autograd/__init__.py?line=154'>155</a>     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     <a href='file:///c%3A/Users/jerem/miniconda3/envs/climatehack/lib/site-packages/torch/autograd/__init__.py?line=155'>156</a>     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
print(agent._q_network)
print(env.counts)

s = sum(env.counts.values())
print({a: env.counts[a] / s for a in env.counts})

# %%
plt.title("Loss")
plt.plot(env.metric_history)
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
plt.title("Rewards")
plt.plot(env.rewards)
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
N = 20

plt.title("Rolling average of rewards")
plt.plot(np.convolve(env.rewards, np.ones(N), mode='valid') / N)
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
plt.title("Cumulative reward")
plt.plot(np.cumsum(env.rewards))
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
plt.title("Cumulative regret (vs cooperating)")
plt.plot(np.cumsum(3 - np.array(env.rewards)))
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
plt.title("Cooperation over the epochs")
print(env.normalised_epoch_counts)
plt.plot([x[Action.COOPERATE] for x in env.normalised_epoch_counts])
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
# torch.save(agent._q_network.state_dict(), "model.pt")

# %%
agent._q_network.eval()

# %%
tournament = RoundRobinTournament(AGENTS, [agent])

scores, times = tournament.play(
    continuation_probability=0.99654, repetitions=20, jobs=12
)

results = [
    (agent, round(sum(scores[agent]) / len(scores[agent])), sum(times[agent]))
    for agent in scores
]
results.sort(key=lambda x: x[1], reverse=True)

for c, score, time in results:
    print(f"{c.__name__:<30} {score:<20} {time:<20}")
